# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters())

# %%
from evolutionSimulation.python.neuralnetworks.nn import * 

model = Brain()

# %%
count_parameters(model)
# Out:
# 2818

# %%
param_size = 0

for param in model.parameters():
    param_size += param.nelement() * param.element_size()
buffer_size = 0
for buffer in model.buffers():
    buffer_size += buffer.nelement() * buffer.element_size()

size_all_mb = (param_size + buffer_size) / 1024**2
print('model size: {:.3f}MB'.format(size_all_mb))
# Out:
# model size: 0.011MB

# %%
#conda_env: evolution
from nn import Brain
from explore_nn import *


brain1 = Brain()
brains = ["C:/Users/allan/nvim/projects/evolutionSimulation/evolutionSimulation/simpleModelWeights/10000/model2.pt", "C:/Users/allan/nvim/projects/evolutionSimulation/evolutionSimulation/simpleModelWeights/5000/model2.pt", "C:/Users/allan/nvim/projects/evolutionSimulation/evolutionSimulation/simpleModelWeights/100/model2.pt"]

brainWeights = []

#brain1.load_state_dict(torch.load(r"C:/Users/allan/nvim/projects/evolutionSimulation/evolutionSimulation/modelWeights/10000/model2.pt"))

for i in brains:
    temp_brain = Brain()
    temp_brain.load_state_dict(torch.load(r"{}".format(i)))
    brainWeights.append(temp_brain)

brainWeights.append(brain1)


print("Compare 10000, 10000")
compareParams(brainWeights[0], brainWeights[0])
print("--------------------------------")

print("Compare 10000, 5000")
compareParams(brainWeights[0], brainWeights[1])
print("--------------------------------")

print("Compare 10000, 100")
compareParams(brainWeights[0], brainWeights[2])
print("--------------------------------")

print("Compare 10000, base")
compareParams(brainWeights[0], brainWeights[3])
print("--------------------------------")

print("Compare 5000, 100")
compareParams(brainWeights[1], brainWeights[2])
print("--------------------------------")

print("Compare 5000, base")
compareParams(brainWeights[1], brainWeights[3])
print("--------------------------------")

print("Compare 100, base")
compareParams(brainWeights[2], brainWeights[3])
print("--------------------------------")

print("Compare base, base")
compareParams(brainWeights[3], brainWeights[3])
print("--------------------------------")
# Out:
# Compare 10000, 10000
# Name: conv1 || Module: Conv2d(1, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# conv1 is the same
# ---------------------------
# Name: pool || Module: MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
# ---------------------------
# Name: conv2 || Module: Conv2d(8, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# conv2 is the same
# ---------------------------
# Name: fc1 || Module: Linear(in_features=784, out_features=2, bias=True)
# fc1 is the same
# ---------------------------
# Identical Model
# --------------------------------
# Compare 10000, 5000
# Name: conv1 || Module: Conv2d(1, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# conv1 is different
# Cosine similarity for conv1: 0.1111111119389534
# ---------------------------
# Name: pool || Module: MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
# ---------------------------
# Name: conv2 || Module: Conv2d(8, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# conv2 is different
# Cosine similarity for conv2: -0.012587943114340305
# ---------------------------
# Name: fc1 || Module: Linear(in_features=784, out_features=2, bias=True)
# fc1 is different
# Cosine similarity for fc1: 0.008145145140588284
# ---------------------------
# 0.10666831396520138
# --------------------------------
# Compare 10000, 100
# Name: conv1 || Module: Conv2d(1, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# conv1 is different
# Cosine similarity for conv1: 0.02777777798473835
# ---------------------------
# Name: pool || Module: MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
# ---------------------------
# Name: conv2 || Module: Conv2d(8, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# conv2 is different
# Cosine similarity for conv2: -0.00959097407758236
# ---------------------------
# Name: fc1 || Module: Linear(in_features=784, out_features=2, bias=True)
# fc1 is different
# Cosine similarity for fc1: 0.004609773866832256
# ---------------------------
# 0.022796577773988247
# --------------------------------
# Compare 10000, base
# Name: conv1 || Module: Conv2d(1, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# conv1 is different
# Cosine similarity for conv1: -0.1388888955116272
# ---------------------------
# Name: pool || Module: MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
# ---------------------------
# Name: conv2 || Module: Conv2d(8, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# conv2 is different
# Cosine similarity for conv2: 0.022336112335324287
# ---------------------------
# Name: fc1 || Module: Linear(in_features=784, out_features=2, bias=True)
# fc1 is different
# Cosine similarity for fc1: -0.0341876819729805
# ---------------------------
# -0.1507404651492834
# --------------------------------
# Compare 5000, 100
# Name: conv1 || Module: Conv2d(1, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# conv1 is different
# Cosine similarity for conv1: -0.1944444477558136
# ---------------------------
# Name: pool || Module: MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
# ---------------------------
# Name: conv2 || Module: Conv2d(8, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# conv2 is different
# Cosine similarity for conv2: 0.007966081611812115
# ---------------------------
# Name: fc1 || Module: Linear(in_features=784, out_features=2, bias=True)
# fc1 is different
# Cosine similarity for fc1: 0.036801036447286606
# ---------------------------
# -0.14967732969671488
# --------------------------------
# Compare 5000, base
# Name: conv1 || Module: Conv2d(1, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# conv1 is different
# Cosine similarity for conv1: 0.1388888955116272
# ---------------------------
# Name: pool || Module: MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
# ---------------------------
# Name: conv2 || Module: Conv2d(8, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# conv2 is different
# Cosine similarity for conv2: 0.03056725487112999
# ---------------------------
# Name: fc1 || Module: Linear(in_features=784, out_features=2, bias=True)
# fc1 is different
# Cosine similarity for fc1: 0.02253279648721218
# ---------------------------
# 0.19198894686996937
# --------------------------------
# Compare 100, base
# Name: conv1 || Module: Conv2d(1, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# conv1 is different
# Cosine similarity for conv1: -0.2222222238779068
# ---------------------------
# Name: pool || Module: MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
# ---------------------------
# Name: conv2 || Module: Conv2d(8, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# conv2 is different
# Cosine similarity for conv2: 0.039128389209508896
# ---------------------------
# Name: fc1 || Module: Linear(in_features=784, out_features=2, bias=True)
# fc1 is different
# Cosine similarity for fc1: -0.01577981747686863
# ---------------------------
# -0.19887365214526653
# --------------------------------
# Compare base, base
# Name: conv1 || Module: Conv2d(1, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# conv1 is the same
# ---------------------------
# Name: pool || Module: MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
# ---------------------------
# Name: conv2 || Module: Conv2d(8, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# conv2 is the same
# ---------------------------
# Name: fc1 || Module: Linear(in_features=784, out_features=2, bias=True)
# fc1 is the same
# ---------------------------
# Identical Model
# --------------------------------
